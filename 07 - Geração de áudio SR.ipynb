# %% [markdown]
# ##Dados do Algoritmo
#
# Autor(a): Simone Rodrigues da Silva (SRS ou 2R)
#
# Data: 20/06/2023 (inicial)
#
# Versão: 1.3
#
# Última atualização: 15.09.2023
#
# Objetivo:
#
# Entregas:
#
# Observações:

# %%
#
# !pip install gtts
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2023.7.22)

# %%
# tarnformando Texto em Voz usando o Google Speech
from gtts import gTTS # importamos o modúlo gTTS

# %%
# Montar o Drive usando código
my_data_folder = 'Projetos de Data Science/TCC/Arquivos/Textos para Speech Recognition/'

from IPython.display import Image as img # Importa função para abrir imagens
from IPython.display import YouTubeVideo as video # Importa função para passar vídeos
from google.colab import drive # Importa método para trabalhar com as pastas do Google Drive

drive.mount('/content/gdrive') # Monta e disponibiliza o sistema de arquivos no Colab (linux)
# Navega para a sua pasta de arquivos das aulas
# %cd gdrive/MyDrive/{my_data_folder}
! ls # Comando do linux para listar o conteúdo da pasta de trabalho ativa
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/MyDrive/Projetos de Data Science/TCC/Arquivos/Textos para Speech Recognition/'
# /content/gdrive/MyDrive/Projetos de Data Science/TCC/Arquivos/Textos para Speech Recognition
# 'Meu Primeiro Amigo é um Tapado - S1E1 gerado SR.mp3'   Texto2.txt
#  Texto10.txt					        Texto3.txt
#  Texto11.txt					        Texto4.txt
#  Texto12.txt					        Texto5.txt
#  Texto13.txt					        Texto6.txt
#  Texto1.txt

# %%
#
arquivo1 = 'Meu Primeiro Amigo é um Tapado - S1E1 gerado SR'
arquivo2 = 'Those Snow White Notes - S1E2 gerado SR'
arquivo3 = 'Fuyu No Hanashi - Centimillimental gerado SR'
arquivo4 = 'Hikariare - Burnout Syndromes gerado SR'
arquivo5 = 'Fuyu No Hanashi Vocal - Centimillimental gerado SR'
arquivo6 = 'Hikariare Vocal - Burnout Syndromes gerado SR'

# %%
#
arq_1 = open("Texto1.txt")
linhas_1 = arq_1.readlines()
for linha_1 in linhas_1:
    print(linha_1)

voz_1 = gTTS(linha_1, lang ="pt") # guardamos o nosso texto na variavel voz
voz_1.save(f'{arquivo1}.mp3')
# Out:
# Nishimura-san, está sempre escuro. Realmente parece a morte. Bom dia. Fui para a morte de manhã. Você está amaldiçoado, Ceifador. Faça uma barreira, Ceifador. O dia em que eu estava fraco demais para sorrir. Não havia tal coisa como uma regra implícita do vento soprando. Desisti da batalha. Eu estava sorrindo levemente no meu coração. Havia uma música que dizia que eu levaria seus sentimentos a sério. Na verdade, estava se movendo. Estou morto. Não consigo colocar em palavras. Se eu notar a qualquer momento, vou gostar mais de você do que deveria. Obrigado. Serei varrido não por palavras, mas por pessoas agora. Gostaria de ter continuado. Bom dia. Bom dia e pessoal. Bom dia. Eu vi o drama de ontem. Antes desse livro, Shinigami o leu. Nishimura, não toque. Parece um shinigami com uma maldição. Nishimura-san, olha, eu me pergunto se é uma maldição sobre o peixinho dourado. Não, é assustador. Sou um peixinho dourado que não se tornou uma piranha. Sou um estudante transferido. Ah, não sei por que, mas Nishimura san do Shinigami, por que ele é chamado assim? Que apelido legal. Nishimura-san, Nishimura-san, uh, Takada-kun, eu gostaria de te perguntar uma coisa. Por que Nishimura se chama Shinigami? Acho que é porque parece um peixe. Tenho pensado nisso desde o dia em que me transferi da escola. Tudo bem, e Takada-kun deve ficar longe de mim. Parece que a maldição é legal, então se você se aproximar ou me tocar, ela vai te infectar. A maldição da morte. A maldição da morte é uma coisa tão hedionda que um aluno do ensino fundamental é incrível. Legal. Sim, não é nada bom. Todos ignoram, e é tão poderoso. Eu também quero. Por que, mesmo que a morte seja legal e nada seja feito, ela pode ser evitada? É tão assustador. Poder Poder Você pode tocar Nishimura-san, então vou tirar sarro dele depois que ele me disser qual é a maldição. Quero que me digam Eu quero que me digam Eu quero que me digam Eu quero que me digam Eu sou como um companheiro de Shinigami Está tudo bem Se você acha que está se dando bem comigo Você pode preferir que lhe digam algo pior.

# %%
#
arq_2 = open("Texto2.txt")
linhas_2 = arq_2.readlines()
for linha_2 in linhas_2:
    print(linha_2)

voz_2 = gTTS(linha_2, lang ="pt") # guardamos o nosso texto na variavel voz
voz_2.save(f'{arquivo2}.mp3')
# Out:
# O xadrez está morto, seu shamisen. Não faça isso. Fique aqui até encontrar um lugar para o que quer fazer e para onde quer ir. Entrei na casa porque pensei que você não era nada como eu. Agora eu te conheço. Saí do escritório. Originalmente, eu estava vazio. Não me diga. Sou eu quem não tem nada. Por que estou no torneio? Não consigo ouvir o som da casa dos meus pais. A mulher está formigando e interessada. É doloroso e frio. Eu sou uma pequena ameaça. Uma música que finalmente acorda e vai para um mundo que brilha branco puro. Prepare-se para ser implacável e bom. Esconda-se no escuro. Caindo na ponta dos meus dedos minúsculos, você será traída se for para a neve, mas não se vire para a sua barriga, meu colégio. Os ânimos estão furiosos agora. Vou ouvir a sua mão enquanto pinta a cidade de branco. Está gravado na parte de trás da Faculdade de Aplausos, então vou transformá-lo em um mestre trêmulo. Vou pintar todas as feridas do passado e tremer. Amar e não. Umeko O que aconteceu? Por que Umeko saiu em Tóquio no festival do quarto da Yuna-san? Não posso deixá-la como mãe. Viva aqui a partir de hoje. O que é arbitrário? Nada como uma mãe até agora. Certamente, sou uma pessoa que ensinou meu filho a relaxar e Tsugaru saiu. Que Matsugoro morreu e Tsugaru saiu sem você. É uma criança pequena que morreu e meu filho foi para a cama. Tsugaru, estou com fome. Eu não quero ver o filme com a minha música Don 't squeeze me Don' t squeeze me In the end, I 'll close it by myself and let all the people here turn around Tsugaru Oharabushi express the beautiful expression of apples, but it' s like a woman 's life. Era uma música que eu desenhava com frequência, mesmo que fosse a primeira vez e tivesse uma força de fundo como a que eu estava me movendo. Amanhã está bom. Sim. Sim, eu não gosto dessa mãe, mas mesmo que Izu ouça isso, seu coração treme e ele é corajoso o suficiente para nascer no dia de suas memórias, e ele certamente esperará pelo momento em que descansará. Sobre você que herdou o sangue de Matsugoro, sinto muito. Sim, sim, sim, por favor, seja alegre. Esta voz.

# %%
#
arq_3 = open("Texto3.txt")
linhas_3 = arq_3.readlines()
for linha_3 in linhas_3:
    print(linha_3)

voz_3 = gTTS(linha_3, lang ="pt") # guardamos o nosso texto na variavel voz
voz_3.save(f'{arquivo3}.mp3')
# Out:
# Agora, me escute, ainda é inverno, e o tempo não acabou. Parece neve na sombra, e eu estou vivo. Eu não posso pilotar esse amor em nenhuma língua, todos vocês. Como eu que não posso dizer adeus e ainda pára ou é uma maldição, um sonho em que estou pensando para você também? Que tipo de pessoas eu tenho nesta cidade? Fingir ser gentil e conhecer o amor. Havia alguém que estava longe, alguém que poderia viver em mim para sempre, mesmo que você não quisesse me deixar em paz. Caminhamos juntos até o fim. Obrigado.

# %%
#
arq_4 = open("Texto4.txt")
linhas_4 = arq_4.readlines()
for linha_4 in linhas_4:
    print(linha_4)

voz_4 = gTTS(linha_4, lang ="pt") # guardamos o nosso texto na variavel voz
voz_4.save(f'{arquivo4}.mp3')
# Out:
# As pessoas que inalam o ar tão cheio que inflamam as células do corpo parecem deixar os idiotas venderem para o mundo. Grite com o volume! Haja luz, haja luz, haja luz à sua maneira e acredite na glória daquele que está diante de você. Amigável, eu serei uma luz amanhã quando o brilho desse rosto se perder, Tera-chan. Uma parede imponente, uma coisa franca, uma coisa boa, uma coisa esperançosa, uma lua, uma pequena possibilidade, uma coragem de acreditar, um grito em volume, uma luz para brilhar. Nos dias em que eu lutar comigo mesmo, não voltarei atrás e continuarei a segui-lo. A luz que eu chamo de luz de preparação, vai. Use a escuridão como um guia e siga o seu próprio caminho. Sempre que a luz se arrasta para o desespero à frente, acredite no eco do dia e vá com a luz A estrela cadente não está mais lá Antes de salvar vidas A luz que brilha em seu coração. A luz do mundo quando você abriu o amanhã de hoje e fez as coisas diferentes!

# %%
#
arq_5 = open("Texto5.txt")
linhas_5 = arq_5.readlines()
for linha_5 in linhas_5:
    print(linha_5)

voz_5 = gTTS(linha_5, lang ="pt") # guardamos o nosso texto na variavel voz
voz_5.save(f'{arquivo5}.mp3')
# Out:
# Vamos ouvir sobre o inverno. Não consigo nem ficar de vigia agora. Estou vivo com pensamentos como neve sombria, e sei que esse amor pode ser qualquer coisa, menos certo e errado. [いっしょに] /juntos/. Que tipo de língua procuro nesta cidade? Fingir ser gentil e conhecer o amor. Eu só quero te dizer que havia alguém que estava longe, que você e tudo o mais não precisam estar sem forma para viver em mim. Obrigado.

# %%
#
arq_6 = open("Texto6.txt")
linhas_6 = arq_6.readlines()
for linha_6 in linhas_6:
    print(linha_6)

voz_6 = gTTS(linha_6, lang ="pt") # guardamos o nosso texto na variavel voz
voz_6.save(f'{arquivo6}.mp3')
# Out:
# O pensamento de respirar o ar o máximo possível para causar um incêndio nas células do corpo é dar as mãos e sujar a caixa Gritar a luz com volume. Que haja luz, que haja luz, voe seu caminho para sempre, acredite na glória do novo trabalho para o desespero do futuro, onde não há luz. Ok, mãe, vamos. Eu sou a luz. Vamos ter um amanhã onde eu possa perder o brilho de hoje. Deixaria? Os fã-clubes nas paredes soviéticas usam coisas como esperança. Por quê? As possibilidades são levantadas num instante. Muito alinhado com os dias em que luto comigo mesmo, não vou me curvar e pescar. Quando continuarei preparado para chamar isso de luz? A luz vai ser diferente. Escreverei a escuridão e abrirei meu próprio caminho. Luz, sempre que há desespero, acredito na maior glória da Disney, a música, as estrelas cadentes, a luz que poupará sua vida esta noite, seu brilho hoje. Ilumine o amanhã dos seus filhos Descanse tranquilo Estrelas de luz.
