# %% [markdown]
# ## Dados do Algoritmo - Usando OpenAi
#
# #Autor(a): Simone Rodrigues da Silva (SRS ou 2R)
# #Data:       09/07/2023 (inicial)
# #Versão:     1.2
# #Última atualização: 17.07.2023
#
# #Objetivo:
#
# #Entregas:
#
#
# #Observações:

# %%
#
import pandas as pd

# %%
# Montar o Drive usando código
my_data_folder = 'Projetos de Data Science/TCC/Arquivos/'

from IPython.display import Image as img # Importa função para abrir imagens
from IPython.display import YouTubeVideo as video # Importa função para passar vídeos
from google.colab import drive # Importa método para trabalhar com as pastas do Google Drive

drive.mount('/content/gdrive') # Monta e disponibiliza o sistema de arquivos no Colab (linux)
# Navega para a sua pasta de arquivos das aulas
# %cd gdrive/MyDrive/{my_data_folder}
! ls # Comando do linux para listar o conteúdo da pasta de trabalho ativa
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/MyDrive/Projetos de Data Science/TCC/Arquivos/'
# /content/gdrive/MyDrive/Projetos de Data Science/TCC/Arquivos
# 'Fuyu No Hanashi - Centimillimental.json'
# 'Fuyu No Hanashi - Centimillimental.mp4'
# 'Fuyu No Hanashi - Centimillimental OpenAi.csv'
# 'Fuyu No Hanashi - Centimillimental OpenAi Ingles.csv'
# 'Fuyu No Hanashi - Centimillimental.srt'
# 'Fuyu No Hanashi - Centimillimental.tsv'
# 'Fuyu No Hanashi - Centimillimental.txt'
# 'Fuyu No Hanashi - Centimillimental.vtt'
# 'Fuyu No Hanashi Vocal - Centimillimental.json'
# 'Fuyu No Hanashi Vocal - Centimillimental.mp3'
# 'Fuyu No Hanashi Vocal - Centimillimental OpenAi.csv'
# 'Fuyu No Hanashi Vocal - Centimillimental OpenAi  Ingles.csv'
# 'Fuyu No Hanashi Vocal - Centimillimental.srt'
# 'Fuyu No Hanashi Vocal - Centimillimental.tsv'
# ...

# %%
# !pip install openai
# !apt install ffmpeg
# !pip install tqdm   #tratamento de loops e mostra seu progresso - Criar barra de progresso
# !pip install git+https://github.com/openai/whisper.git

import tqdm
import openai
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-fbfdh7rx
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-fbfdh7rx
#   Resolved https://github.com/openai/whisper.git to commit 0a60fcaa9b86748389a656aa013c416030287d47
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
#xport OPENAI_API_KEY='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'
#openai.api_key = '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'

# %%
#
Arquivo_1 = 'Meu Primeiro Amigo é um Tapado - S1E1 OpenAi'
Arquivo_2 = 'Those Snow White Notes - S1E2 OpenAi'
Arquivo_3 = 'Fuyu No Hanashi - Centimillimental OpenAi'
Arquivo_4 = 'Hikariare - Burnout Syndromes OpenAi'
Arquivo_5 = 'Fuyu No Hanashi Vocal - Centimillimental OpenAi'
Arquivo_6 = 'Hikariare Vocal - Burnout Syndromes OpenAi'

Arquivo_1I = 'Meu Primeiro Amigo é um Tapado - S1E1 OpenAi Ingles'
Arquivo_2I = 'Those Snow White Notes - S1E2 Ingles'
Arquivo_3I = 'Fuyu No Hanashi - Centimillimental OpenAi Ingles'
Arquivo_4I = 'Hikariare - Burnout Syndromes OpenAi Ingles'
Arquivo_5I = 'Fuyu No Hanashi Vocal - Centimillimental OpenAi Ingles'
Arquivo_6I = 'Hikariare Vocal - Burnout Syndromes OpenAi Ingles'

Arquivo_1P = 'Meu Primeiro Amigo é um Tapado - S1E1 OpenAi Port'
Arquivo_2P = 'Those Snow White Notes - S1E2 Port'
Arquivo_3P = 'Fuyu No Hanashi - Centimillimental OpenAi Port'
Arquivo_4P = 'Hikariare - Burnout Syndromes OpenAi Port'
Arquivo_5P = 'Fuyu No Hanashi Vocal - Centimillimental OpenAi Port'
Arquivo_6P = 'Hikariare Vocal - Burnout Syndromes OpenAi Port'

# %%
#
texto_1 = []
texto_1= !whisper "Meu Primeiro Amigo é um Tapado - S1E1.mp4" --language Japanese

# %%
#
texto_2 = []
texto_2= !whisper "Those Snow White Notes - S1E2.mp4" --language Japanese

# %%
#
texto_3 = []
texto_3= !whisper "Fuyu No Hanashi - Centimillimental.mp4" --language Japanese

# %%
#
texto_4 = []
texto_4= !whisper "Hikariare - Burnout Syndromes.mp4" --language Japanese

# %%
#
texto_5 = []
texto_5= !whisper "Fuyu No Hanashi Vocal - Centimillimental.mp3" --language Japanese

# %%
#
texto_6 = []
texto_6= !whisper "Hikariare Vocal - Burnout Syndromes.mp3" --language Japanese

# %%
#
arquivo_Transcricao_1_OpenAi = pd.DataFrame(texto_1,columns=['transcricao'])
arquivo_Transcricao_1_OpenAi.to_csv(f'{Arquivo_1}.csv')

arquivo_Transcricao_2_OpenAi = pd.DataFrame(texto_2,columns=['transcricao'])
arquivo_Transcricao_2_OpenAi.to_csv(f'{Arquivo_2}.csv')

arquivo_Transcricao_3_OpenAi = pd.DataFrame(texto_3,columns=['transcricao'])
arquivo_Transcricao_3_OpenAi.to_csv(f'{Arquivo_3}.csv')

arquivo_Transcricao_4_OpenAi = pd.DataFrame(texto_4,columns=['transcricao'])
arquivo_Transcricao_4_OpenAi.to_csv(f'{Arquivo_4}.csv')

arquivo_Transcricao_5_OpenAi = pd.DataFrame(texto_5,columns=['transcricao'])
arquivo_Transcricao_5_OpenAi.to_csv(f'{Arquivo_5}.csv')

arquivo_Transcricao_6_OpenAi = pd.DataFrame(texto_6,columns=['transcricao'])
arquivo_Transcricao_6_OpenAi.to_csv(f'{Arquivo_6}.csv')

# %%
texto_1I = !whisper "Meu Primeiro Amigo é um Tapado - S1E1.mp4" --language Japanese --task translate

# %%
texto_2I= !whisper "Those Snow White Notes - S1E2.mp4"  --language Japanese --task translate

# %%
texto_3I= !whisper "Fuyu No Hanashi - Centimillimental.mp4" --language Japanese --task translate

# %%
texto_4I= !whisper "Hikariare - Burnout Syndromes.mp4" --language Japanese --task translate

# %%
texto_5I= !whisper "Fuyu No Hanashi Vocal - Centimillimental.mp3" --language Japanese --task translate

# %%
texto_6I= !whisper "Hikariare Vocal - Burnout Syndromes.mp3" --language Japanese --task translate

# %%
#
arquivo_Transcricao_1I_OpenAi_Ingles = pd.DataFrame(texto_1I,columns=['transcricao'])
arquivo_Transcricao_1I_OpenAi_Ingles.to_csv(f'{Arquivo_1I}.csv')

arquivo_Transcricao_2I_OpenAi_Ingles = pd.DataFrame(texto_2I,columns=['transcricao'])
arquivo_Transcricao_2I_OpenAi_Ingles.to_csv(f'{Arquivo_2I}.csv')

arquivo_Transcricao_3I_OpenAi_Ingles = pd.DataFrame(texto_3I,columns=['transcricao'])
arquivo_Transcricao_3I_OpenAi_Ingles.to_csv(f'{Arquivo_3I}.csv')

arquivo_Transcricao_4I_OpenAi_Ingles = pd.DataFrame(texto_4I,columns=['transcricao'])
arquivo_Transcricao_4I_OpenAi_Ingles.to_csv(f'{Arquivo_4I}.csv')

arquivo_Transcricao_5I_OpenAi_Ingles = pd.DataFrame(texto_5I,columns=['transcricao'])
arquivo_Transcricao_5I_OpenAi_Ingles.to_csv(f'{Arquivo_5I}.csv')

arquivo_Transcricao_6I_OpenAi_Ingles = pd.DataFrame(texto_6I,columns=['transcricao'])
arquivo_Transcricao_6I_OpenAi_Ingles.to_csv(f'{Arquivo_6I}.csv')

# %%
#import whisper

#model = whisper.load_model("base")

# load audio and pad/trim it to fit 30 seconds
#audio = whisper.load_audio("Fuyu No Hanashi - Centimillimental.mp4")
#audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
#mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect the spoken language
#_, probs = model.detect_language(mel)
#print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
#options = whisper.DecodingOptions()
#result = whisper.decode(model, mel, options)

# print the recognized text
#print(result.text)

# %%
#
# !pip install googletrans==3.1.0a0

# %%
#  Avaliar os textos gerados da transcrição do vídeo versus o texto original


# Texto gerado pelo arquivo de vídeo completo
arq_1 = open("Texto1.txt")
linhas_arq_1 = arq_1.readlines()
for linha_arq_1 in linhas_arq_1:
  linha_arq_1


# Texto gerado pelo arquivo de vídeo completo
arq_2 = open("Texto2.txt")
linhas_arq_2 = arq_2.readlines()
for linha_arq_2 in linhas_arq_2:
  linha_arq_2

# Texto gerado pelo arquivo de vídeo completo
arq_3 = open("Texto3.txt")
linhas_arq_3 = arq_3.readlines()
for linha_arq_3 in linhas_arq_3:
  linha_arq_3

# Texto gerado pelo arquivo de vídeo completo
arq_4 = open("Texto4.txt")
linhas_arq_4 = arq_4.readlines()
for linha_arq_4 in linhas_arq_4:
  linha_arq_4

# Texto gerado pelo arquivo de vídeo completo
arq_5 = open("Texto5.txt")
linhas_arq_5 = arq_5.readlines()
for linha_arq_5 in linhas_arq_5:
  linha_arq_5

# Texto gerado pelo arquivo de vídeo completo
arq_6 = open("Texto6.txt")
linhas_arq_6 = arq_6.readlines()
for linha_arq_6 in linhas_arq_6:
  linha_arq_6

# %%
linha_arq_6
# Out:
# "This is the first time I've seen this kind of video. I'm not sure if this is the first time I've seen this kind of video. I'm not sure if this is the first time I've seen this kind of video. I'm not sure if this is the first time I've seen this kind of video.This is the first time I've seen   kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of video. This is the first time I've seen this kind of